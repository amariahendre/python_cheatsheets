# %%
import datetime

# %%
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2023, 4, 10, 9, 39, 18, 545249)

# %%
date_object = datetime.date(2023, 4, 10)
date_object
# Out:
# datetime.date(2023, 4, 10)

# %%
time_object = datetime.time(9, 45, 45, 60)
time_object
# Out:
# datetime.time(9, 45, 45, 60)

# %%
datetime_object = datetime.datetime.combine(date_object, time_object)
datetime_object
# Out:
# datetime.datetime(2023, 4, 10, 9, 45, 45, 60)

# %%
from datetime import date, time, datetime, timedelta
D  = date(year=2023, month=4, day=10)
T  = time(hour=0, minute=0, second=0, microsecond=0, tzinfo=None, fold=0)
DT = datetime(year=2023, month=4, day=10, hour=0, minute=0, second=0)
TD = timedelta(days=0, seconds=0, microseconds=0, milliseconds=0,
                 minutes=0, hours=0, weeks=0)

# %%
day_of_week = datetime_object.weekday()
day_of_week
# Out:
# 0

# %%
day_of_year = datetime_object.timetuple().tm_yday
day_of_year
# Out:
# 100

# %%
from datetime import date, time, datetime, timedelta
new_datetime_object = datetime.now() + timedelta(days=1, hours=2, minutes=30)
new_datetime_object
# Out:
# datetime.datetime(2023, 4, 11, 12, 11, 57, 487844)

# %%
timestamp = datetime_object.timestamp()
timestamp

# %%
date.today()
# Out:
# datetime.date(2023, 4, 10)

# %%
utc_now = datetime.utcnow()
utc_now
# Out:
# datetime.datetime(2023, 4, 10, 9, 45, 14, 105349)
